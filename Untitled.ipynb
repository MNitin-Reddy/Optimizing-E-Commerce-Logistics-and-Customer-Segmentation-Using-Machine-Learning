# %% [markdown]
# # Improving Delivery Efficiency and Customer Segmentation in E-Commerce
#
# #### Domain: E-commerce
#
# ## **Problem Statement**
# In the fast-paced e-commerce industry, timely delivery and personalized customer engagement are critical for maintaining a competitive edge. However, delays and cancellations in order deliveries are common and occur due to inconsistent logistics operations, lack of proactive planning, and unforeseen supply chain disruptions. These inefficiencies are often accepted as part of operations but have a significant impact on customer satisfaction, loyalty, and business reputation. These delays not only frustrate customers but also lead to increased returns, cancellations, and negative brand perception.
#
# Additionally, a lack of proper customer segmentation results in generic marketing strategies and poorly targeted loyalty programs. Without understanding customer behavior, businesses fail to differentiate between high-value customers and those driven by discounts, leading to missed opportunities to enhance customer retention and profitability. These issues collectively impact customer satisfaction, operational efficiency, and long-term growth.
#
# Similarly, most e-commerce platforms rely on broad, one-size-fits-all marketing strategies, missing opportunities to cater to diverse customer preferences. Customers exhibit varied behaviors, such as high-frequency purchasing, discount sensitivity, or region-specific needs, which often go unaddressed. This lack of tailored approaches leaves room for improvement in both operational efficiency and customer engagement.
#
# ### **How AI Helps**
# AI presents a transformative opportunity to address these challenges by leveraging advanced data analytics and machine learning techniques. Predictive models can analyze historical order and shipping data to identify patterns that lead to delivery delays or cancellations. By proactively flagging high-risk orders, businesses can optimize their logistics, reallocate resources, and notify customers in advance, significantly improving delivery reliability and customer satisfaction.
#
# Similarly, AI-driven clustering techniques can segment customers based on their purchasing behavior, order frequency, and profitability. This allows businesses to uncover hidden patterns, design personalized marketing campaigns, and prioritize high-value customers. By turning data into actionable insights, AI enables e-commerce platforms to move beyond generic strategies, creating tailored solutions that enhance customer loyalty and operational efficiency.
#
# ## **Objective**
# 1. **Classification Task:** Predict delivery delays and cancellations using machine learning to proactively address potential disruptions, improve logistics, and enhance delivery reliability, ultimately reducing customer dissatisfaction and operational costs.
# 2. **Clustering Task:** Segment customers based on spending habits, order frequency, and profitability to enable personalized marketing, loyalty programs, and region-specific strategies, improving customer retention and resource optimization.

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Overview

# %%
# importing the data
data = pd.read_csv(r"Ecommerce_data.csv")
data.head()
# Out:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
# 2  C_ID_70880                Mary             Gayman  Office Supplies
# 3  C_ID_33157             Raymond              Eason  Office Supplies
# 4  C_ID_58303                Mary           Gonzalez        Furniture
#
#                            product_name customer_segment customer_city  \
# 0                            Xerox 1913        Corporate  New Rochelle
# 1    #6 3/4 Gummed Flap White Envelopes        Corporate       Houston
# 2       Belkin 8 Outlet Surge Protector         Consumer    Louisville
# 3  GBC VeloBinder Manual Binding System        Corporate       Chicago
# 4         Eldon Pizzaz Desk Accessories      Home Office  Philadelphia
#
#   customer_state customer_country customer_region  ...  order_date  \
# ...

# %% [markdown]
# Here's a brief description of each column in the dataset:
#
# 1. **customer_id**: Unique identifier for each customer, used for tracking individual purchases and behaviors.
# 2. **customer_first_name**: First name of the customer for personal identification.
# 3. **customer_last_name**: Last name of the customer for personal identification.
# 4. **category_name**: Category of the product purchased, such as "Office Supplies" or "Furniture."
# 5. **product_name**: The name of the specific product ordered, e.g., "Xerox 1913" or "Belkin 8 Outlet Surge Protector."
# 6. **customer_segment**: Classification of customers into segments like "Corporate," "Home Office," or "Consumer" based on their business relationship or purchasing behavior.
# 7. **customer_city**: The city where the customer resides.
# 8. **customer_state**: The state or region where the customer resides.
# 9. **customer_country**: The country where the customer is located.
# 10. **customer_region**: The broader geographical region (e.g., East, West, South, North) where the customer is based.
# 11. **delivery_status**: The delivery status of the order, which could be "Shipping on time," "Late delivery," or "Shipping canceled."
# 12. **order_date**: The date when the customer placed the order.
# 13. **order_id**: Unique identifier for each order, helping to link various order details together.
# 14. **ship_date**: The date when the order was actually shipped out.
# 15. **shipping_type**: The shipping method used, such as "Standard Class" or "Second Class."
# 16. **days_for_shipment_scheduled**: The number of days the order was scheduled to take for delivery.
# 17. **days_for_shipment_real**: The actual number of days it took for the order to be delivered.
# 18. **order_item_discount**: The discount applied to the items in the order.
# 19. **sales_per_order**: The total sales value for the order.
# 20. **order_quantity**: The quantity of items ordered in the specific order.
# 21. **profit_per_order**: The profit earned on the order after all expenses.
#
# These columns capture a blend of customer demographics, product details, and logistical aspects, making the dataset useful for analyzing operational performance and customer behaviors in e-commerce.

# %%
print("No of rows and columns in the data: ", data.shape)
# Out:
# No of rows and columns in the data:  (113270, 21)

# %% [markdown]
# * The dataset mirrors the type of data used by e-commerce companies to track key customer behaviors, order details, and logistics, making it highly relevant for tackling real-world operational challenges. It offers insights into issues such as **delivery delays** and **cancellations**, as well as **customer segmentation** for personalized marketing strategies. With features like shipping details, order information, and customer demographics, the dataset can be used to predict delivery outcomes (classification) and segment customers based on purchasing patterns and profitability (clustering).
#
#
# * The size and complexity of the dataset further enhance its value. It includes a variety of features such as numerical data (e.g., sales, profit), categorical data (e.g., customer segments, delivery status), and time-related attributes (e.g., order and shipping dates). This diversity makes the dataset suitable for both classification and clustering tasks, offering a comprehensive view of e-commerce operations.
#
#
#
# * By analyzing this data, businesses can address critical challenges that directly impact **customer satisfaction**, **loyalty**, and **operational efficiency**. It enables companies to enhance **logistics operations**, reduce delays, and offer better customer service. Additionally, it aids in **targeting the right customer segments** with tailored marketing strategies, ultimately improving **customer retention** and boosting **revenue**. This makes the dataset a valuable resource for driving improvements in e-commerce business performance and decision-making.

# %% [markdown]
# **Let's have deeper look into the data**
#
# We'll look into the data understand its size, the null values, view the numerical and categorical columns check if there are any inconsistensis, check for duplicated records, chcek if there are any outliers present in numerical columns

# %% [markdown]
# ### Data Exploration
#
# In this section, we will perform a detailed exploration of the dataset to understand its structure and quality. We will examine the following aspects:
#
# - **Size of the Data**: Check the dimensions of the dataset to understand its scale.
# - **Missing Values**: Identify any null or missing values in the dataset.
# - **Numerical and Categorical Columns**: Categorize and analyze the numerical and categorical features to ensure correct data representation.
# - **Inconsistencies**: Look for any inconsistencies or errors within the data.
# - **Duplicated Records**: Detect and handle any duplicate entries in the dataset.
# - **Outliers**: Investigate if any numerical columns contain outliers that could impact model performance.
#
# This step will help ensure the dataset is clean and ready for further analysis and model development.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113270 entries, 0 to 113269
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   customer_id                  113270 non-null  object
#  1   customer_first_name          113270 non-null  object
#  2   customer_last_name           113270 non-null  object
#  3   category_name                113270 non-null  object
#  4   product_name                 113270 non-null  object
#  5   customer_segment             113270 non-null  object
#  6   customer_city                113270 non-null  object
#  7   customer_state               113270 non-null  object
#  8   customer_country             113270 non-null  object
#  9   customer_region              113270 non-null  object
#  10  delivery_status              113270 non-null  object
#  11  order_date                   113270 non-null  object
# ...

# %% [markdown]
# **Observation:**
# - The dataset contains 113,270 entries and 21 columns in total.
# - There are 3 **float64**, 3 **int64**, and 15 **object** columns.

# %% [markdown]
# ### Null values check

# %%
data.isnull().sum()
# Out:
# customer_id                    0
# customer_first_name            0
# customer_last_name             0
# category_name                  0
# product_name                   0
# customer_segment               0
# customer_city                  0
# customer_state                 0
# customer_country               0
# customer_region                0
# delivery_status                0
# order_date                     0
# order_id                       0
# ship_date                      0
# shipping_type                  0
# days_for_shipment_scheduled    0
# days_for_shipment_real         0
# order_item_discount            0
# sales_per_order                0
# order_quantity                 0
# profit_per_order               0
# dtype: int64

# %% [markdown]
# - There are no null values present in the data, indicating it is complete for analysis.

# %% [markdown]
# ### Duplicated records

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are no duplicated records

# %% [markdown]
# ### Looking at the Categorical columns

# %%
categorical_cols = list(data.select_dtypes(include = 'object').columns)
data[categorical_cols].head(2)
# Out:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
#
#                          product_name customer_segment customer_city  \
# 0                          Xerox 1913        Corporate  New Rochelle
# 1  #6 3/4 Gummed Flap White Envelopes        Corporate       Houston
#
#   customer_state customer_country customer_region    delivery_status  \
# 0       New York    United States            East   Shipping on time
# 1          Texas    United States         Central  Shipping canceled
#
#    order_date      order_id   ship_date shipping_type
# 0   11/5/2022  O_ID_3001072   11/7/2022  Second Class
# 1  20-06-2022  O_ID_3009170  23-06-2022  Second Class

# %%
for i in categorical_cols:
    print('*'*10 + ' ' + i + ' ' + '*'*10)
    values = set(data[i])
    if len(values) > 50:
        print('Number of Unique values:' , len(values))
    else:
        print(values)
    print()
# Out:
# ********** customer_id **********
# Number of Unique values: 42047
#
# ********** customer_first_name **********
# Number of Unique values: 757
#
# ********** customer_last_name **********
# Number of Unique values: 586
#
# ********** category_name **********
# {'Technology', 'Furniture', 'Office Supplies'}
#
# ********** product_name **********
# Number of Unique values: 1849
#
# ********** customer_segment **********
# {'Consumer', 'Corporate', 'Home Office'}
#
# ********** customer_city **********
# Number of Unique values: 531
#
# ********** customer_state **********
# ...

# %% [markdown]
# #### Observations:
#
# - **`customer_id`** and **`order_id`**: Unique identifiers with no significance for predicting delivery delays or customer segmentation.
#
# - **`customer_first_name`** and **`customer_last_name`**: Not relevant for analysis, as names don’t impact delivery or segmentation.
#
# - **`category_name`**: Three product categories (**Technology**, **Furniture**, **Office Supplies**) that can influence delivery patterns and customer segmentation.
#
# - **`product_name`**: With 1,849 unique products, this helps in understanding customer preferences and grouping.
#
# - **`customer_segment`**: Segments like **Consumer**, **Corporate**, and **Home Office** are important for clustering and analyzing delivery behavior.
#
# - **`customer_city`** and **`customer_state`**: Geographical data impacting delivery logistics and potential delays.
# - **`customer_country`**: Only **United States**, not adding variability.
# - **`customer_region`**: Four regions (**South**, **Central**, **West**, **East**) are useful for understanding regional delivery performance.
# - **`delivery_status`**: Key for classification (**target feature**), indicating the delivery outcome (on time, canceled, late).
# - **`order_date`** and **`ship_date`**: Important for analyzing timing patterns in deliveries.
# - **`shipping_type`**: Influences delivery times and delays, relevant for analysis.

# %%
numerical_cols = list(data.select_dtypes(exclude='object').columns)
numerical_cols
# Out:
# ['days_for_shipment_scheduled',
#  'days_for_shipment_real',
#  'order_item_discount',
#  'sales_per_order',
#  'order_quantity',
#  'profit_per_order']

# %%
data.describe()
# Out:
#        days_for_shipment_scheduled  days_for_shipment_real  \
# count                113270.000000           113270.000000
# mean                      2.931209                3.464006
# std                       1.375914                1.632198
# min                       0.000000                0.000000
# 25%                       2.000000                2.000000
# 50%                       4.000000                3.000000
# 75%                       4.000000                5.000000
# max                       4.000000                6.000000
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order
# count        113270.000000    113270.000000   113270.000000     113270.000000
# mean             21.105465       204.499537        1.967564         23.069382
# std              22.959207       141.443090        1.355254        105.288561
# min               0.000000         9.990000        1.000000      -3366.000000
# ...

# %%
for i in numerical_cols:
    print('*'*10 + ' ' + i + ' ' + '*'*10)
    values = set(data[i])
    if len(values) > 50:
        print('Number of Unique values:' , len(values))
    else:
        print(values)
    print()
# Out:
# ********** days_for_shipment_scheduled **********
# {0, 1, 2, 4}
#
# ********** days_for_shipment_real **********
# {0, 1, 2, 3, 4, 5, 6}
#
# ********** order_item_discount **********
# Number of Unique values: 1017
#
# ********** sales_per_order **********
# Number of Unique values: 209
#
# ********** order_quantity **********
# {1, 2, 3, 4, 5}
#
# ********** profit_per_order **********
# Number of Unique values: 19140

# %% [markdown]
# ### Insights from Numerical Columns:
#
# - **`days_for_shipment_scheduled`** and **`days_for_shipment_real`**: Both columns have fewer than 5 unique values, suggesting they behave more like categorical variables. The values range from 0 to 4 (for scheduled) and 0 to 6 (for real), which may indicate predefined categories of shipment duration.
#
# - **`order_item_discount`**: While there are 1,017 unique values, it has a wide range (from 0 to 500), with a significant concentration of values around 0 to 30. Since the values move above 100 we can consider the values represent the amount deducted from the price and does not represent the percentage
#
# - **`sales_per_order`**: Similar to order_item_discount, this column has 209 unique values. The mean sales per order is about 204, with some extreme values (up to 1999), showing variability in order sizes or product prices.
#
# - **`order_quantity`**: With values ranging from 1 to 5, this is a categorical-like variable, showing limited variation in the number of items per order.
#
# - **`profit_per_order`**: With 19,140 unique values, this column has a broad range of values from **negative to positive**. The negative values need closer inspection as they can represent be key indicators or can be errors introduced while data entry.
#
# * **Overall, while some numerical columns may seem continuous, they exhibit characteristics of categorical data.**
# * **Since the dataset lacks clear descriptions, we must infer the meaning of the columns based on the observed data**
# * **There are columns `profit_per_order` which needs further inspection.**
# * **The continuous columns might have outliers as observed from the difference in the 75th percentile and the maximum values of these columns**

# %%
# looking at negative values in profit_per_order
data[data['profit_per_order'] < 0][['order_item_discount', 'sales_per_order', 'order_quantity','profit_per_order']].shape
# Out:
# (21177, 4)

# %% [markdown]
# In the dataset, there are **21,177 rows with profit values less than 0**, indicating that these orders may represent losses, possibly due to reasons like:
#
# - Discounts or promotions leading to negative profit margins.
# - Shipping costs exceeding the sales price.
# - Mispricing or operational errors.
#
# Since we lack details about the product's cost price and selling price (which is often not provided by sellers), it is challenging to definitively interpret the cause of these negative profits.
#
# However, these losses are not uncommon in real-world e-commerce scenarios, where businesses may offer deep discounts, cover high shipping costs, or experience errors in pricing.
#
# For our analysis, we'll **acknowledge these negative profit values** but proceed with caution.

# %% [markdown]
# ### Outlier detection

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 8))
ax = ax.flatten()

for i, col in enumerate(numerical_cols):
    sns.boxplot(data=data[col], ax=ax[i])
    ax[i].set_title(f'{col}')
    ax[i].set_ylabel("")

fig.tight_layout()
plt.show()

# %% [markdown]
# **Explanation:**
#
# 1. **`sales_per_order`:** The outliers here can indeed be attributed to high-priced items. As the maximum order quantity is only 5, bulk orders are unlikely to be the cause. Therefore, it is reasonable to assume that these outliers are the result of products with higher cost or value, which might be considered luxury items or large equipment.
#
# 2. **`order_item_discount`:** High discounts could explain the presence of outliers, as discounts might be applied to special promotions, or seasonal sales. These can cause large deviations from the normal discount range. Again, without further details on pricing strategies, it's tough to fully explain the outliers, but it's a reasonable assumption.
#
# 3. **`profit_per_order`:** The presence of negative or extreme values likely represents losses or items sold at a loss. However, without information on the actual cost and selling prices, it's difficult to assess the exact cause of these losses. It could be due to markdowns, poor pricing strategies, or other factors.
#
# **"These outliers should be handled effectively to ensure unbiased results from the model. To mitigate their impact, appropriate transformations can be applied, reducing their influence on the model's performance."**

# %% [markdown]
# ## Overview of Data Exploration
#
# * **Shape and Data Types**:
#   The dataset has 113,270 entries and 21 columns. Among these, we have:
#   - 3 `float64` columns (for numerical data)
#   - 3 `int64` columns (for numerical data)
#   - 15 `object` columns (categorical data)
#
# * **Null Values and Duplicates**:
#   There are **no null values** in the dataset, ensuring completeness of the data. Additionally, **no duplicated records** were found.
#
# * **Categorical Data Observations**:
#   - Columns like `category_name`, `customer_segment`, `customer_country`, and `delivery_status` have relatively fewer unique values (e.g., 'Office Supplies', 'Consumer', 'Shipping on time').
#   - Customer IDs and Order IDs have a large number of unique values but do not contribute directly to predicting delivery delays or customer segmentation, so they were excluded from further analysis.
#   - Other columns like `customer_state` and `customer_city` have a diverse set of values, providing useful demographic data for customer segmentation.
#   - `customer_country` has only one values United States. IT doesn't have any variability, doesn't contribute much to the analysis.
#
# * **Numerical Data Observations**:
#   - We have numerical columns such as `days_for_shipment_scheduled`, `days_for_shipment_real`, `order_item_discount`, `sales_per_order`, `order_quantity`, and `profit_per_order`.
#   - Interestingly, three of these columns (`days_for_shipment_scheduled`, `days_for_shipment_real`, and `order_quantity`) show a categorical-like nature due to having fewer unique values (e.g., values like 1, 2, 3 for `order_quantity`).
#   - Columns like `sales_per_order` and `profit_per_order` exhibit significant outliers. These outliers are mostly linked to high-priced items or large discounts, which are not typical in most orders. However, the lack of detailed product pricing information complicates precise interpretation.
#
# * **Outliers**:
#   - **`sales_per_order`** shows outliers that likely represent high-priced items. The presence of bulk orders is minimized due to the `order_quantity` column, which has a maximum value of 5, reinforcing the idea that these outliers are due to high-value items rather than bulk purchases.
#   - **`order_item_discount`** and **`profit_per_order`** contain outliers, particularly in the higher range. These could be explained by significant discounts or losses, but without additional cost information, it's challenging to draw exact conclusions.
#
# * **Irregularities**:
#   - The presence of negative profit values (losses) adds complexity, as it’s difficult to confirm their validity due to the lack of cost and pricing information.
#   - The `order_date` and `ship_date` columns are currently in different formats, with some values using `'-'` and others using `'/'`. This inconsistency needs to be addressed before performing any feature generation or transformation involving these columns.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.head()
# Out:
#   customer_id customer_first_name customer_last_name    category_name  \
# 0  C_ID_45866                Mary             Fuller  Office Supplies
# 1  C_ID_44932                Alan            Edelman  Office Supplies
# 2  C_ID_70880                Mary             Gayman  Office Supplies
# 3  C_ID_33157             Raymond              Eason  Office Supplies
# 4  C_ID_58303                Mary           Gonzalez        Furniture
#
#                            product_name customer_segment customer_city  \
# 0                            Xerox 1913        Corporate  New Rochelle
# 1    #6 3/4 Gummed Flap White Envelopes        Corporate       Houston
# 2       Belkin 8 Outlet Surge Protector         Consumer    Louisville
# 3  GBC VeloBinder Manual Binding System        Corporate       Chicago
# 4         Eldon Pizzaz Desk Accessories      Home Office  Philadelphia
#
#   customer_state customer_country customer_region  ...  order_date  \
# ...

# %%
#Since cutomer_id, order_id, cusotmer_first_name, customer_last_name, order_id, customer_country 
# we make a new dataframe without these columns for analysis.

df = data.drop(columns= ['customer_id','customer_first_name','customer_last_name','order_id','customer_country'])
df.head()
# Out:
#      category_name                          product_name customer_segment  \
# 0  Office Supplies                            Xerox 1913        Corporate
# 1  Office Supplies    #6 3/4 Gummed Flap White Envelopes        Corporate
# 2  Office Supplies       Belkin 8 Outlet Surge Protector         Consumer
# 3  Office Supplies  GBC VeloBinder Manual Binding System        Corporate
# 4        Furniture         Eldon Pizzaz Desk Accessories      Home Office
#
#   customer_city customer_state customer_region    delivery_status  order_date  \
# 0  New Rochelle       New York            East   Shipping on time   11/5/2022
# 1       Houston          Texas         Central  Shipping canceled  20-06-2022
# 2    Louisville       Kentucky           South      Late delivery  25-06-2022
# 3       Chicago       Illinois         Central      Late delivery   10/6/2022
# 4  Philadelphia   Pennsylvania            East      Late delivery    2/5/2022
#
# ...

# %% [markdown]
# #### Exploring the target variable

# %%
df['delivery_status'].value_counts()
# Out:
# delivery_status
# Late delivery        62051
# Advance shipping     25930
# Shipping on time     20393
# Shipping canceled     4896
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4)) 

ax1 = sns.barplot(data=df['delivery_status'].value_counts(), ax=ax[0], palette='Set2',legend = 'brief', orient = 'x')
ax[0].set_title('Delivery status Barplot')
ax[0].set_xlabel('Status')
ax[0].set_ylabel('Count')
ax[0].yaxis.set_ticks([])
ax[0].tick_params(axis='x', rotation=15)


for p in ax1.patches:
    ax1.annotate(f'{int(p.get_height())}',
                 (p.get_x() + p.get_width() / 2, p.get_height()),
                 ha='center', va='center', xytext=(0, 5), textcoords='offset points')

ax[1].pie(df['delivery_status'].value_counts(), autopct="%1.1f%%", colors=sns.color_palette('Set2'))
ax[1].set_title('Delivery status Pie Chart')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
# - **54.8%** of deliveries are delayed, indicating a major issue with delivery timeliness.
# - **4.3%** of orders are canceled, suggesting potential operational inefficiencies.
# - **22.9%** of orders are shipped in advance, reflecting proactive supply chain management.
# - Only **18%** of deliveries are on time, highlighting the need for better logistics and forecasting.

# %% [markdown]
# ### Analysing Numerical columns

# %%
continuous_cols = ['order_item_discount','sales_per_order','profit_per_order']

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 6))
ax = ax.flatten()

for i, col in enumerate(continuous_cols):
    sns.histplot(data=df[col], ax=ax[i], kde=True, bins = 50)
    ax[i].set_title(f'{col}')
    ax[i].set_ylabel("")
    ax[i].lines[0].set_color('crimson')

fig.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
#
# - The `order_item_discount` column is highly right-skewed, with most discounts being either 0 or around 30.
# - The `sales_per_order` column shows a right-skewed distribution, with fluctuations and no clear normal pattern, suggesting variations in order values.
# - The `profit_per_order` column exhibits both left and right tails with numerous outliers. However, the majority of the profits are concentrated between 0 and 100.

# %% [markdown]
# ### Analysing categorical columns

# %%
df.columns
# Out:
# Index(['category_name', 'product_name', 'customer_segment', 'customer_city',
#        'customer_state', 'customer_region', 'delivery_status', 'order_date',
#        'ship_date', 'shipping_type', 'days_for_shipment_scheduled',
#        'days_for_shipment_real', 'order_item_discount', 'sales_per_order',
#        'order_quantity', 'profit_per_order'],
#       dtype='object')

# %%
category_cols = ['category_name', 'customer_segment', 'customer_region', 'shipping_type', 'days_for_shipment_scheduled',
       'days_for_shipment_real']
# since product_name, customer_state, customer_city have high number of unique values representing almost all the major states and cities we analyse them seperately

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 8)) 
ax = ax.flatten()

for i,col in enumerate(category_cols):
    ax[i] = sns.barplot(data=df[col].value_counts(), ax=ax[i], palette='Set2', )
    ax[i].set_title(f'{col}')
    ax[i].set_ylabel('Count')
    ax[i].yaxis.set_ticks([])
    for p in ax[i].patches:
        ax[i].annotate(f'{int((p.get_height()/113270)*100)}%',
                 (p.get_x() + p.get_width() / 2, p.get_height()),
                 ha='center', va='center', xytext=(0, 5), textcoords='offset points')


plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**:
#
# - **`category_name`**: 60% of orders are for office supplies, with the rest for furniture and technology.
# - **`customer_segment`**: Half of the orders are placed by the consumer segment, followed by corporate and home office segments.
# - **`customer_region`**: Most orders are from the West region, with the South having the least orders (16%).
# - **`shipping_type`**: 60% of orders are shipped using standard class, followed by second class, first class, and only 5% for same-day delivery.
# - **`days_for_shipment_scheduled`**: 60% of orders are scheduled for 4-day delivery, showing a preference for this time window.
# - **`days_for_shipment_real`**: 31% of deliveries are completed within 2 days, and 15% fall within the 3-6 day range. Deliveries are being delayed in most of the cases.

# %% [markdown]
# ### Date columns Analysis

# %%
# Replace '/' with '-' in both columns to unify the delimiter
df['order_date'] = df['order_date'].str.replace('/', '-', regex=False)
df['ship_date'] = df['ship_date'].str.replace('/', '-', regex=False)

df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')
df['ship_date'] = pd.to_datetime(df['ship_date'], format='%d-%m-%Y')

# %%
df[['order_date','ship_date']].describe()
# Out:
#                           order_date                      ship_date
# count                         113270                         113270
# mean   2021-12-11 19:54:08.613048576  2021-12-14 16:48:40.427297536
# min              2021-01-04 00:00:00            2021-01-05 00:00:00
# 25%              2021-06-22 00:00:00            2021-06-25 00:00:00
# 50%              2021-12-06 00:00:00            2021-12-09 00:00:00
# 75%              2022-05-31 00:00:00            2022-06-02 00:00:00
# max              2022-12-31 00:00:00            2023-03-04 00:00:00

# %%
The records represent the details of orders dform 2021 january to year 2023

# %%
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month

# Group by year and month, and count the number of orders per period
orders_per_month = df.groupby(['year', 'month']).size().reset_index(name='order_count')

plt.figure(figsize=(8, 4))
sns.lineplot(x='month', y='order_count', hue='year', data=orders_per_month, marker='o', palette='Set2')

plt.title('Orders Over the Years and Months')
plt.xlabel('Month')
plt.ylabel('Number of Orders')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title='Year')
# plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Observations:**
# - In **2021**, the orders showed steady growth, with a noticeable **spike in March**. After March, the order numbers **remained consistent** for the rest of the year.
# - In **2022**, the early months followed a similar trend to **2021**, but there was a **significant drop in the number of orders** from **October to December**. This drop in orders may indicate a decline in customer interest or trust, possibly due to factors like delayed deliveries.
# - The **overall performance in 2022 was lower** compared to 2021, with fewer orders throughout the year.
# - The high rate of **delayed deliveries (54%)** might have played a significant role in the **decreased order numbers** during the latter part of 2022, potentially leading to **customer dissatisfaction and loss of trust** in the service.

# %%
Bi variate Analysis: 
    Analyze the relationship between the target variable and other columns

# %%
df.head()
# Out:
#      category_name                          product_name customer_segment  \
# 0  Office Supplies                            Xerox 1913        Corporate
# 1  Office Supplies    #6 3/4 Gummed Flap White Envelopes        Corporate
# 2  Office Supplies       Belkin 8 Outlet Surge Protector         Consumer
# 3  Office Supplies  GBC VeloBinder Manual Binding System        Corporate
# 4        Furniture         Eldon Pizzaz Desk Accessories      Home Office
#
#   customer_city customer_state customer_region    delivery_status order_date  \
# 0  New Rochelle       New York            East   Shipping on time 2022-05-11
# 1       Houston          Texas         Central  Shipping canceled 2022-06-20
# 2    Louisville       Kentucky           South      Late delivery 2022-06-25
# 3       Chicago       Illinois         Central      Late delivery 2022-06-10
# 4  Philadelphia   Pennsylvania            East      Late delivery 2022-05-02
#
# ...

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 25))
axes = axes.flatten()  # Flatten axes for easier indexing

fig.suptitle("Analysis of Binary Yes/No Categorical Columns by Claim Status", fontsize=16, y=1.0)
# Iterate over categorical variables and plot
for i, column in enumerate(list(categorical_columns.iloc[:,8::].columns)):
    order = data[column].value_counts().index
    ax1 = sns.countplot(data=data, x=column,hue='is_claim', ax=axes[i], order=order)
    axes[i].set_title(f'Count of {column}')
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x labels for readability
    for p in ax1.patches:
        ax1.annotate(f'{int(p.get_height())}',
                 (p.get_x() + p.get_width() / 2, p.get_height()),
                 ha='center', va='center', xytext=(0, 5), textcoords='offset points')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 16)) 
ax = ax.flatten()

for i,col in enumerate(category_cols):
    order = df[col].value_counts().index
    ax[i] = sns.countplot(data=df, x=col,hue='delivery_status', ax=ax[i], order=order, palette='Set2')
    ax[i].set_title(f'{col}')
    ax[i].set_ylabel('Count')
    ax[i].yaxis.set_ticks([])
    for p in ax[i].patches:
        ax[i].annotate(f'{int(p.get_height())}',
                 (p.get_x() + p.get_width() / 2, p.get_height()),
                 ha='center', va='center', xytext=(0, 5), textcoords='offset points')


plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**:
# - **Late Delivery**: Late deliveries are observed across all categories, indicating that there is no specific category with a significantly higher number of late deliveries.
# - **Days for Shipment**: Late deliveries occur more frequently on days 2, 5, and 6, showing potential delays during those time frames.
# - **Shipping Type**: Only the standard shipping class has seen advance shipping. It also has a higher proportion of late deliveries compared to others.
# - **First Class Shipping**: **All first-class orders are delayed, with no on-time deliveries. This is a significant observation, indicating that first-class shipping may not be reliable for timely deliveries.**

# %%
# Target variable vs continuous columns (e.g., sales_per_order, order_quantity, etc.)
plt.figure(figsize=(8, 2))
sns.boxplot(data=data, x='delivery_status', y='sales_per_order')
plt.title('Delivery Status vs Sales per Order')
plt.show()

plt.figure(figsize=(8, 2))
sns.boxplot(data=data, x='delivery_status', y='order_quantity')
plt.title('Delivery Status vs Order Quantity')
plt.show()

plt.figure(figsize=(8, 2))
sns.boxplot(data=data, x='delivery_status', y='profit_per_order')
plt.title('Delivery Status vs Profit per Order')
plt.show()

# %% [markdown]
# **Observation:**
# - **`sales_per_order`**: There is no clear distinction between delivery status categories. The median and range appear similar across all statuses, indicating that the price of orders does not strongly influence delivery delays or cancellations.
# - **`order_quantity`**: The order quantity also shows no significant variation across delivery statuses, as the majority of orders are concentrated around smaller quantities.
# - **`profit_per_order`**: The distribution of profits is similar for all delivery statuses, with outliers present in every category. This suggests that profit margins do not have a strong impact on delivery outcomes.
#
# These insights indicate that the continuous variables may not have a strong predictive relationship with the target variable directly. Further feature engineering or interaction terms might reveal latent patterns.

# %% [markdown]
# ### Key Insights from EDA:
# - **Target Variable (`delivery_status`)**:
#   - 54.8% of orders are delayed, which highlights a significant logistical issue.
#   - 22.9% of deliveries are shipped in advance, while 18% are on time, and 4.3% orders are canceled.
#
# - **Categorical Features**:
#   - **`category_name`**: Around 60% of the orders are for office supplies, followed by technology and furniture.
#   - **`customer_segment`**: The consumer segment contributes to 50% of orders, with corporate and home office making up the rest.
#   - **`customer_region`**: The West region places the highest number of orders (27%), with the South being the least (16%).
#   - **`shipping_type`**: Most shipments are of Standard Class (60%), followed by Second Class (25%) and First Class (10%), with Same Day delivery accounting for just 5%.
#   - **`days_for_shipment_scheduled` vs. `days_for_shipment_real`**: Although 60% of orders are scheduled for a 4-day delivery, most orders are delivered within 2 days.
#
# - **Numerical Features**:
#   - **Outliers**: Significant outliers are present in `sales_per_order`, `order_item_discount`, and `profit_per_order`, which will need handling during preprocessing.
#   - **Skewness**: `order_item_discount` is highly right-skewed, with most discounts being 0 or near 30%. Similarly, `sales_per_order` and `profit_per_order` show right-tailed distributions.
#   - **Profit Analysis**: Around 21,177 records show negative profits, likely representing losses. These may need careful consideration for model robustness.
#
# - **Temporal Analysis**:
#   - Orders span from January 2021 to 2023. A drop in orders was observed in late 2022, possibly due to customer dissatisfaction from delayed deliveries.
#   - Orders peak consistently in March and remain steady through most of 2021, but late 2022 saw a significant decline in performance.

# %% [markdown]
# ## Feature Engineering
#
# 1. **Remove columns that won't have any predictive power**
#    We begin by identifying and removing columns that are unlikely to contribute to the predictive power of the model, such as `customer_id`,`customer_first_name`,`customer_last_name`,`order_id`,`customer_country`, as it won't help with our objective.
#
# 2. **Convert columns into their respective datatypes**
#    We convert the `order_date` and `ship_date` columns into `datetime` format. Address the inconsistency of date delimiters being both '-' and '/'.
#
# 3. **Extract month and year details of the order**
#    From the `order_date`, we extract the `year` and `month`. These new features may capture seasonal trends or time-related patterns that could be important in predicting delivery statuses.
#
# 4. **Multicollinearity check of Numerical columns**
#    We calculate the correlation matrix of numerical columns (`sales_per_order`, `order_quantity`, and `profit_per_order`). If any two columns have a correlation higher than 0.9, we would consider dropping one of them to avoid multicollinearity, which can provide redundant information and may contribute to noise within the model.
#
# 5. **Chi-squared tests to check the most important categorical features**
#    We perform chi-squared tests on the categorical features to assess which ones are most significantly related to the target variable (`delivery_status`). This helps identify the most important features for model training.
#
# 6. **Train Test Split**
#     * The dataset is split into training and testing sets to ensure the model is evaluated on data it hasn't seen during training. This helps avoid data leakage and ensures that the transformations or scaling applied during preprocessing don't affect the model's generalization to new, unseen data. This step is crucial for building a reliable and unbiased model.
#
# 7. **Scale numerical features and encode categorical columns**
#    * We scale the numerical features (such as `sales_per_order`, `order_quantity`, and `profit_per_order`) using `StandardScaler` to ensure all features contribute equally to the model.
#
#    * For categorical columns, we apply one-hot encoding or label encoding to transform them into numerical form, allowing the model to interpret these features effectively.

# %% [markdown]
# **Dropping columns `customer_id`,`customer_first_name`,`customer_last_name`,`order_id`,`customer_country`**

# %%
final_df = data.drop(columns= ['customer_id','customer_first_name','customer_last_name','order_id','customer_country'])

# %% [markdown]
# **Converting `order_date` and `ship_date` to datetime and extracting month and year features**

# %%
# Replace '/' with '-' in both columns to unify the delimiter
final_df['order_date'] = final_df['order_date'].str.replace('/', '-', regex=False)
final_df['ship_date'] = final_df['ship_date'].str.replace('/', '-', regex=False)

final_df['order_date'] = pd.to_datetime(final_df['order_date'], format='%d-%m-%Y')
final_df['ship_date'] = pd.to_datetime(final_df['ship_date'], format='%d-%m-%Y')

# %%
final_df['order_year'] = final_df['order_date'].dt.year
final_df['order_month'] = final_df['order_date'].dt.month

# %%
final_df = final_df.drop(columns = ['ship_date','order_date']) # dropping these columns as we already have month and year

# %% [markdown]
# **Multicollinearity check**

# %%
final_df.columns
# Out:
# Index(['category_name', 'product_name', 'customer_segment', 'customer_city',
#        'customer_state', 'customer_region', 'delivery_status', 'shipping_type',
#        'days_for_shipment_scheduled', 'days_for_shipment_real',
#        'order_item_discount', 'sales_per_order', 'order_quantity',
#        'profit_per_order', 'order_year', 'order_month'],
#       dtype='object')

# %%
continuous_cols = ['order_item_discount','sales_per_order', 'order_quantity','profit_per_order']

# %%
sns.heatmap(final_df[continuous_cols].corr(method = 'spearman'), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Observation:**
# * While `sales_per_order` has moderate correlations with `order_item_discount` (0.51) and `profit_per_order` (0.42), none of the features are highly correlated to the point where they would cause significant multicollinearity. These columns each contribute valuable and unique information about the sales, profit, and order patterns, which can help the model capture different aspects of the delivery process. Therefore, we decide to keep all four columns (`order_item_discount`, `sales_per_order`, `order_quantity`, `profit_per_order`) for further analysis and model development.

# %% [markdown]
# **Chi-squared test**
#
# * A **chi-squared test (also chi-square or χ2 test)** is a statistical hypothesis test that is valid to perform when the test statistic is chi-squared distributed under the null hypothesis, specifically Pearson's chi-squared test
#
# * A chi-square statistic is one way to show a relationship between two categorical variables.
#
# * Here we test correlation of Categorical columns with Target column i.e `delivery_status`
# ---
#
# * **Null Hypothesis:** The feature is independent of target column (No-Correlation)
# * **Alternate Hypothesis:** The feature and target column are not independent (Correlated)

# %%
cat_columns = ['category_name', 'product_name', 'customer_segment','order_quantity', 'customer_city',
       'customer_state', 'customer_region', 'delivery_status', 'shipping_type', 'days_for_shipment_scheduled',
       'days_for_shipment_real', 'order_year', 'order_month']

# %%
from scipy.stats import chi2_contingency
chi2_test = []
for feature in cat_columns:
    if chi2_contingency(pd.crosstab(final_df['delivery_status'], final_df[feature]))[1] < 0.05:
        chi2_test.append('Reject Null Hypothesis')
    else:
        chi2_test.append('Fail to Reject Null Hypothesis')
result = pd.DataFrame(data=[cat_columns,chi2_test]).T
result.columns = ['Column', 'Hypothesis Result']
result
# Out:
#                          Column               Hypothesis Result
# 0                 category_name  Fail to Reject Null Hypothesis
# 1                  product_name  Fail to Reject Null Hypothesis
# 2              customer_segment          Reject Null Hypothesis
# 3                order_quantity          Reject Null Hypothesis
# 4                 customer_city          Reject Null Hypothesis
# 5                customer_state          Reject Null Hypothesis
# 6               customer_region          Reject Null Hypothesis
# 7               delivery_status          Reject Null Hypothesis
# 8                 shipping_type          Reject Null Hypothesis
# 9   days_for_shipment_scheduled          Reject Null Hypothesis
# 10       days_for_shipment_real          Reject Null Hypothesis
# 11                   order_year          Reject Null Hypothesis
# 12                  order_month          Reject Null Hypothesis

# %% [markdown]
# **Observation:**
#
# - **`category_name`** and **`product_name`**:
#   - Both columns failed to reject the null hypothesis, indicating they don't provide significant information to predict the **`delivery status`**. These features likely don't have a strong relationship with the target variable and may not be useful for the model.

# %%
final_df = final_df.drop(columns = ['category_name','product_name'])

# %%
final_df.columns
# Out:
# Index(['customer_segment', 'customer_city', 'customer_state',
#        'customer_region', 'delivery_status', 'shipping_type',
#        'days_for_shipment_scheduled', 'days_for_shipment_real',
#        'order_item_discount', 'sales_per_order', 'order_quantity',
#        'profit_per_order', 'order_year', 'order_month'],
#       dtype='object')

# %% [markdown]
# **Train Test split**

# %%
X = final_df.drop(columns = ['delivery_status'])
y = final_df['delivery_status']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
X_train.head()
# Out:
#       customer_segment    customer_city customer_state customer_region  \
# 50695      Home Office    San Francisco     California            West
# 40014      Home Office  Charlottesville       Virginia           South
# 77409         Consumer          Chicago       Illinois         Central
# 65910         Consumer    New York City       New York            East
# 89150        Corporate          Seattle     Washington            West
#
#         shipping_type  days_for_shipment_scheduled  days_for_shipment_real  \
# 50695     First Class                            1                       2
# 40014  Standard Class                            4                       3
# 77409  Standard Class                            4                       6
# 65910        Same Day                            0                       1
# 89150     First Class                            1                       2
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order  \
# ...

# %% [markdown]
# **Scaling and Encoding data**

# %%
cat_cols_encode = ['customer_segment', 'customer_city', 'customer_state',
       'customer_region', 'shipping_type']
num_cols_encode = [ 'order_item_discount', 'sales_per_order',
       'order_quantity', 'profit_per_order']

# %% [markdown]
# * Let's first encode categorical columns using LabelEncoder.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler, PowerTransformer

# %%
for col in list(X_train.select_dtypes(include='object')):
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col])
    X_test[col] = le.transform(X_test[col])
    
X_train.head()
# Out:
#        customer_segment  customer_city  customer_state  customer_region  \
# 50695                 2            438               3                3
# 40014                 2             75              44                2
# 77409                 0             80              11                0
# 65910                 0            329              30                1
# 89150                 1            452              45                3
#
#        shipping_type  days_for_shipment_scheduled  days_for_shipment_real  \
# 50695              0                            1                       2
# 40014              3                            4                       3
# 77409              3                            4                       6
# 65910              1                            0                       1
# 89150              0                            1                       2
#
#        order_item_discount  sales_per_order  order_quantity  profit_per_order  \
# ...

# %%
continuous_cols
# Out:
# ['order_item_discount',
#  'sales_per_order',
#  'order_quantity',
#  'profit_per_order']

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[continuous_cols])
X_test_scaled = scaler.transform(X_test[continuous_cols])

# %%
X_train_scaled
# Out:
# array([[-0.48522819, -0.73630661,  0.02485817,  0.01353382],
#        [-0.74809385, -0.5740248 ,  0.02485817,  0.45436984],
#        [-0.15708424,  0.32134738,  2.24193248, -5.7915754 ],
#        ...,
#        [-0.83571573, -1.08909314, -0.7141666 ,  0.01071097],
#        [-0.83571573, -1.15979157,  0.02485817, -0.29839176],
#        [-0.63856649, -0.52470521, -0.7141666 ,  0.13350519]])

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([1, 1, 1, ..., 3, 3, 1])

# %% [markdown]
# ## Model Training
#
# #### Multi-Class Classification:
# - **Model Chosen**: Tree-based models (e.g., Decision Trees, Random Forests, Gradient Boosting)
# - **Rationale**: Given the skewed data, outliers, and non-normal distributions, tree-based models are ideal as they make minimal assumptions about the data. They are robust to outliers and can effectively capture complex patterns and relationships.
# Based on the data we have I believe tree based models like **DecisionTree , RandomForest , GradientBoosting, etc** work the best
# - **Approach**: Train multiple tree-based base models, evaluate them based on metrics like **accuracy, recall, precision, and F1-score**, and select the top-performing model for further refinement by hyper parameter tuning using **GridSerachCV** and further improve the perfromance.

# %%
# importing libraries
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# %%
models = {
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
}

# %%
def train_evaluate_models(X_train,y_train,X_test,y_test,models):
    """
    Trains and evaluates multiple machine learning models on the given dataset.
    Parameters:
    X_train (DataFrame): Training features.
    y_train (Series): Training labels.
    X_test (DataFrame): Test features.
    y_test (Series): Test labels.
    models (dict): Dictionary of models to train with model names as keys.

    Returns:
    DataFrame: A sorted DataFrame with model evaluation metrics (Accuracy, Precision, Recall, ROC_AUC).
    """
    model_list = []
    accuracy_list = []
    precision_list = []
    recall_list = []
    roc_auc_list = []
    for i in range(len(list(models))):
        
        model = list(models.values())[i]
        model.fit(X_train,y_train)
        
        y_train_predicted = model.predict(X_train)
        y_test_predicted = model.predict(X_test)
        # Train set perfromance
        model_train_accuracy, model_train_f1, model_train_precision, model_train_recall = evaluation(y_train,y_train_predicted)
        # Test set performance
        model_test_accuracy, model_test_f1, model_test_precision, model_test_recall = evaluation(y_test,y_test_predicted)
        
        print(list(models.keys())[i])
        model_list.append(list(models.keys())[i]) # append the model to the list
        
        evaluation_scores(y_train,y_test, y_train_predicted,y_test_predicted) #printing the scores
        
        print('='*35)
        print('\n')
        
        # append all the calcualted metrics to the lists
        accuracy_list.append(model_test_accuracy)
        precision_list.append(model_test_precision)
        recall_list.append(model_test_recall)
        
    report = pd.DataFrame(list(zip(model_list,accuracy_list,precision_list,recall_list)),columns = ['Model name','Accuracy','Precision','Recall']).sort_values(by=['Accuracy'],ascending=False)
    return report

# %%
def evaluation(true, predicted):
    """
    Evaluates various metrics of a classification model for multiclass classification.
    """
    acc = accuracy_score(true, predicted)  # Calculate Accuracy
    f1 = f1_score(true, predicted, average='macro')  # Calculate Macro F1-score
    precision = precision_score(true, predicted, average='macro')  # Calculate Macro Precision
    recall = recall_score(true, predicted, average='macro')  # Calculate Macro Recall 
    
    return acc, f1, precision, recall

# %%
def evaluation_scores(y_train,y_test,y_train_predicted,y_test_predicted):
    """
    Evaluates and prints classifications metrics for both test and train sets
    """
    # Training set performance
    model_train_accuracy, model_train_f1, model_train_precision, model_train_recall = evaluation(y_train,y_train_predicted)
    # Test set performance
    model_test_accuracy, model_test_f1, model_test_precision, model_test_recall = evaluation(y_test,y_test_predicted)
        
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1)) 
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    #print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    print('----------------------------------')

    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    #print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

# %%
base_model_report = train_evaluate_models(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,models=models)
# Out:
# Random Forest
# Model performance for Training set
# - Accuracy: 0.9999
# - F1 score: 0.9997
# - Precision: 0.9999
# - Recall: 0.9996
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9559
# - F1 score: 0.7390
# - Precision: 0.9336
# - Recall: 0.7521
# ...
#
#
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9103
# - F1 score: 0.7373
# - Precision: 0.7391
# - Recall: 0.7361
# ...
#
#
# Gradient Boosting
# Model performance for Training set
# - Accuracy: 0.9548
# - F1 score: 0.7361
# - Precision: 0.9666
# - Recall: 0.7497
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9552
# - F1 score: 0.7366
# - Precision: 0.9669
# - Recall: 0.7501
# ...

# %%
base_model_report
# Out:
#           Model name  Accuracy  Precision    Recall
# 0      Random Forest  0.955902   0.933554  0.752137
# 2  Gradient Boosting  0.955196   0.966875  0.750129
# 1      Decision Tree  0.910347   0.739126  0.736073

# %% [markdown]
# ### Model Selection and Observations
#
# - **Performance**: The models perform well on both train and test data. However, there is a slight overfitting observed, as the train performance is marginally better than the test performance.
# - **Chosen Model**: Random Forest was selected for further development due to its robustness, ability to handle complex data patterns, and overall superior performance among the models tested.
# - **Next Steps**: Perform hyperparameter tuning on the Random Forest model to further optimize its performance and reduce overfitting. This involves fine-tuning parameters like the number of estimators, maximum depth, and feature selection to achieve a better balance between train and test accuracy.

# %%
rf_model = RandomForestClassifier(random_state=42)

param_grid = {
    'max_depth': [2,4, 5],           
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],                
    'max_features': ['sqrt', 'log2'],     
}

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2, scoring='accuracy')

grid_search.fit(X_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best Hyperparameters: {best_params}")
print(f"Best Cross-Validation Score: {best_score}")
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best Hyperparameters: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Cross-Validation Score: 0.9131610160214574

# %%
model = RandomForestClassifier(n_estimators=200, max_depth = 8 , max_features = 'sqrt', min_samples_leaf=2, min_samples_split=2)
model.fit(X_train,y_train)
        
y_train_predicted = model.predict(X_train)
y_test_predicted = model.predict(X_test)
        # Train set perfromance
model_train_accuracy, model_train_f1, model_train_precision, model_train_recall = evaluation(y_train,y_train_predicted)
        # Test set performance
model_test_accuracy, model_test_f1, model_test_precision, model_test_recall = evaluation(y_test,y_test_predicted)
        
evaluation_scores(y_train,y_test, y_train_predicted,y_test_predicted) #printing the scores
# Out:
# Model performance for Training set
# - Accuracy: 0.9515
# - F1 score: 0.7318
# - Precision: 0.9620
# - Recall: 0.7487
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9519
# - F1 score: 0.7318
# - Precision: 0.9627
# - Recall: 0.7487

# %%
x

# %% [markdown]
# #### Model Evaluation

# %% [markdown]
# * **Accuracy** "Out of all the orders, how many did the model predict correctly?"
#
# * **Recall (Sensitivity)** "Of all the orders that are actually delayed, how many did the model correctly predict as delayed?"
#
# * **Precision** "Of all the orders the model predicted to be delayed, how many are actually delayed?"
#
# * **F1-Score**  "What is the balance between precision and recall for predicting delayed orders?"

# %%
from sklearn.metrics import classification_report

if hasattr(model, "classes_"):
    target_names = [str(cls) for cls in model.classes_]
else:
    target_names = [str(cls) for cls in set(y_test)]

# Generate and print the classification report
report = classification_report(y_test, y_test_predicted, target_names=target_names)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                    precision    recall  f1-score   support
#
#  Advance shipping       0.94      1.00      0.97      5186
#     Late delivery       0.96      0.99      0.97     12410
# Shipping canceled       1.00      0.00      0.01       979
#  Shipping on time       0.96      1.00      0.98      4079
#
#          accuracy                           0.95     22654
#         macro avg       0.96      0.75      0.73     22654
#      weighted avg       0.95      0.95      0.93     22654

# %%
cm = confusion_matrix(y_test, y_test_predicted)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap="Blues")
plt.xticks(rotation = 15)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# **Features that most contributed to the prediction**

# %% [markdown]
# ### Final Model:
# After experimenting with various models and hyperparameter tuning using GridSearchCV, the **Random Forest Classifier** with the parameters `n_estimators=200`, `max_depth=8`, `max_features='sqrt'`, `min_samples_leaf=2`, and `min_samples_split=2` provided the best performance.
#
# #### Observations:
# 1. **Overall Accuracy**:
#    - The model achieves **95% accuracy**, indicating strong overall performance.
#
# 2. **Class-Wise Insights**:
#    - **Advance Shipping, Late Delivery, Shipping on Time**: The model performs well for these classes, with high precision, recall, and F1-scores.
#    - **Shipping Canceled**: The model struggles with this minority class, showing poor recall and F1-score.
#
# 3. **Minority Class Efforts**:
#    - Several experiments were conducted to improve the performance for the "Shipping Canceled" class, but no significant improvement was observed.
#
# 4. **Objective Alignment**:
#    - Since the primary objective is to predict **Late Delivery**, the model effectively meets this goal with its strong performance on this class.
#
# 5. **Future Improvement**:
#    - Additional features, access to more data, or incorporating domain-specific insights could enhance the model's performance and provide deeper insights from the data.

# %% [markdown]
# Clustering Model
# #### Clustering:
# - **Model Chosen**: KMeans Clustering
# - **Rationale**: KMeans is simple, efficient, and scalable, making it an excellent choice for large datasets. It works well when clusters are relatively distinct, making it effective for customer segmentation or identifying product groups. Its ability to handle large datasets with minimal tuning is a major advantage.
# - **Approach**: Apply KMeans clustering to segment the data, assess clustering quality using metrics like silhouette score, and analyze the resulting clusters to uncover valuable insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Assuming your data is in 'data' DataFrame and has already been preprocessed (cleaned, etc.)

# Step 1: Data Preprocessing
# Selecting relevant numerical columns for clustering
numerical_cols = ['sales_per_order', 'order_quantity', 'profit_per_order']  # Add other relevant columns
X = data[numerical_cols]

# Standardizing the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Step 2: Finding the optimal number of clusters using Elbow Method
inertia = []
for k in range(1, 11):  # Checking from 1 to 10 clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.show()

# %%
# Step 3: Training the K-Means Model (let's say k=4 based on the elbow)
kmeans = KMeans(n_clusters=6, random_state=42)
data['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
# Step 4: Visualizing the clusters using PCA for dimensionality reduction
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=data['Cluster'], cmap='viridis', s=50)
plt.title('Clustering with KMeans (PCA-reduced data)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
# Step 5: Analyze the clusters
# Grouping data by clusters and looking at average feature values
cluster_summary = data.groupby('Cluster')[numerical_cols].mean()
print(cluster_summary)
# Out:
#          sales_per_order  order_quantity  profit_per_order
# Cluster
# 0             350.085842        1.058780         79.890121
# 1             123.993489        1.240908         18.441369
# 2             305.825867        4.655850         71.192359
# 3             293.914875        1.917013       -351.425732
# 4            1500.151305        2.391608        340.036527
# 5             164.712872        3.497597         20.834502

# %%
silhouette_avg = silhouette_score(scaled_data, kmeans.labels_)
# Print the Silhouette Score for 6 clusters
print(f"Silhouette Score for 6 clusters: {silhouette_avg:.4f}")
# Out:
# Silhouette Score for 6 clusters: 0.4296

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sales_per_order', y='profit_per_order', hue='Cluster', data=data, palette='viridis')
plt.title('Clustering of Product Categories based on Sales and Profit')
plt.show()

# %%
data.columns
# Out:
# Index(['customer_id', 'customer_first_name', 'customer_last_name',
#        'category_name', 'product_name', 'customer_segment', 'customer_city',
#        'customer_state', 'customer_country', 'customer_region',
#        'delivery_status', 'order_date', 'order_id', 'ship_date',
#        'shipping_type', 'days_for_shipment_scheduled',
#        'days_for_shipment_real', 'order_item_discount', 'sales_per_order',
#        'order_quantity', 'profit_per_order', 'Cluster'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame

# Step 1: Select relevant columns for segmentation
features = ['order_quantity', 'profit_per_order', 'customer_region', 'category_name']

# Step 2: Handle categorical columns by encoding them
data_encoded = data[features].copy()

# Encode categorical columns (e.g., region, category_name)
label_encoder = LabelEncoder()
data_encoded['customer_region'] = label_encoder.fit_transform(data_encoded['customer_region'])
data_encoded['category_name'] = label_encoder.fit_transform(data_encoded['category_name'])

# Step 3: Normalize the numerical features
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_encoded)

# Step 4: Apply K-Means clustering
kmeans = KMeans(n_clusters=6, random_state=42)  # Number of clusters (e.g., 4)
data['Cluster'] = kmeans.fit_predict(data_normalized)

# Step 5: Visualize the clusters (Optional, 2D PCA for visualization)
# from sklearn.decomposition import PCA

# pca = PCA(n_components=2)
# pca_components = pca.fit_transform(data_normalized)

# # Plot the clusters
# plt.figure(figsize=(10, 6))
# sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=data['Cluster'], palette='Set2', s=100)
# plt.title("Customer Segmentation using K-Means Clustering")
# plt.xlabel("PCA Component 1")
# plt.ylabel("PCA Component 2")
# plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='order_quantity', y='profit_per_order', hue='Cluster', data=data, palette='viridis')
plt.title('Clustering of Product Categories based on Sales and Profit')
plt.show()

# %%
# Step 7: Inspect data with clusters
print("Data with Cluster Labels:\n", data[['sales_per_order', 'order_quantity', 'profit_per_order', 'customer_region', 'category_name', 'Cluster']].head())
# Out:
# Data with Cluster Labels:
#     sales_per_order  order_quantity  profit_per_order customer_region  \
# 0            500.0               5        223.199997            East
# 1            500.0               5        199.199997         Central
# 2             44.0               5        195.500000           South
# 3            254.0               1        220.000000         Central
# 4            500.0               1         97.500000            East
#
#      category_name  Cluster
# 0  Office Supplies        2
# 1  Office Supplies        1
# 2  Office Supplies        2
# 3  Office Supplies        1
# 4        Furniture        1

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Select relevant columns for clustering
clustering_data = data[['sales_per_order', 'profit_per_order', 'order_quantity']]

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(clustering_data)

# Applying KMeans clustering (let's start with 3 clusters)
kmeans = KMeans(n_clusters=3, random_state=42)
data['Cluster'] = kmeans.fit_predict(scaled_data)

# Visualize the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sales_per_order', y='profit_per_order', hue='Cluster', data=data, palette='viridis')
plt.title('Clustering of Product Categories based on Sales and Profit')
plt.show()

# %%
# Display the centroids of the clusters
centroids = kmeans.cluster_centers_
centroids_df = pd.DataFrame(scaler.inverse_transform(centroids), columns=['sales_per_order', 'profit_per_order', 'order_quantity'])
print("Cluster Centers (Centroids):")
print(centroids_df)

# Calculate the mean sales, profit, and order quantity per cluster
cluster_summary = data.groupby('Cluster')[['sales_per_order', 'profit_per_order', 'order_quantity']].mean()
print("Cluster Summary (Average Sales, Profit, and Order Quantity):")
print(cluster_summary)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Selecting relevant columns for clustering
clustering_data = data[['sales_per_order', 'profit_per_order', 'order_quantity']]

# Standardize the features
scaler = StandardScaler()
scaled_data = scaler.fit_transform(clustering_data)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=6, random_state=42)
data['Cluster'] = kmeans.fit_predict(scaled_data)

# Visualizing the clustering results
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sales_per_order', y='profit_per_order', hue='Cluster', data=data, palette='viridis')
plt.title('Clustering of Orders Based on Sales and Profit')
plt.xlabel('Sales per Order')
plt.ylabel('Profit per Order')
plt.legend(title='Cluster')
plt.show()

# %%
# Display the centroids of the clusters
centroids = kmeans.cluster_centers_
centroids_df = pd.DataFrame(scaler.inverse_transform(centroids), columns=['sales_per_order', 'profit_per_order', 'order_quantity'])
print("Cluster Centers (Centroids):")
print(centroids_df)

# Calculate the mean values of each feature per cluster
cluster_summary = data.groupby('Cluster')[['sales_per_order', 'profit_per_order', 'order_quantity']].mean()
print("Cluster Summary (Average Sales, Profit, and Order Quantity):")
print(cluster_summary)
# Out:
# Cluster Centers (Centroids):
#    sales_per_order  profit_per_order  order_quantity
# 0       350.090513         79.889885        1.058869
# 1       123.993489         18.441369        1.240908
# 2       305.854627         71.025664        4.660097
# 3       293.893159       -351.397490        1.917726
# 4      1500.151305        340.036527        2.391608
# 5       164.867144         21.007703        3.496630
# Cluster Summary (Average Sales, Profit, and Order Quantity):
#          sales_per_order  profit_per_order  order_quantity
# Cluster
# 0             350.085842         79.890121        1.058780
# 1             123.993489         18.441369        1.240908
# 2             305.825867         71.192359        4.655850
# 3             293.914875       -351.425732        1.917013
# 4            1500.151305        340.036527        2.391608
# 5             164.712872         20.834502        3.497597

# %%
print("Inertia (sum of squared distances to centroids):", kmeans.inertia_)
# Out:
# Inertia (sum of squared distances to centroids): 90604.57546983231

# %%
silhouette_avg = silhouette_score(scaled_data, kmeans.labels_)
# Print the Silhouette Score for 6 clusters
print(f"Silhouette Score for 6 clusters: {silhouette_avg:.4f}")
# Out:
# Silhouette Score for 6 clusters: 0.4296

# %%
# Subsample 10% of the data
sample_data = X.sample(frac=0.1, random_state=42)
silhouette_score = silhouette_score(sample_data, model.labels_)

# %%
# Elbow Method to determine the optimal number of clusters
inertia_values = []

# Try a range of cluster values (e.g., from 1 to 10 clusters)
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)
    inertia_values.append(kmeans.inertia_)

# Plotting the Elbow Curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia_values, marker='o', color='b')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia (Sum of Squared Distances)')
plt.grid(True)
plt.show()
